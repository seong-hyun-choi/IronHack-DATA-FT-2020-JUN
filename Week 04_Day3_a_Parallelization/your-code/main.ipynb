# %% [markdown]
# # Parallelization Lab
#
# In this lab, you will be leveraging several concepts you have learned to obtain a list of links from a web page and crawl and index the pages referenced by those links - both sequentially and in parallel. Follow the steps below to complete the lab.
#
# ### Step 1: Use the requests library to retrieve the content from the URL below.

# %%
import requests
url = 'https://en.wikipedia.org/wiki/Data_science'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
html = response.content

# %% [markdown]
# ### Step 2: Use BeautifulSoup to extract a list of all the unique links on the page.

# %%
from bs4 import BeautifulSoup

# %%
source = BeautifulSoup(html)

# %%
source.find_all('a')[3].attrs['href']
# Out:
# '/wiki/Information_science'

# %%
source.find_all('a')[3]['href']

lst_link = []
for item in source.find_all('a'):
    if 'href' in item.attrs:
        try:
            if item.attrs['href'].startswith('/wiki'):
                lst_link.append(item.attrs['href'])
        except:
            pass
        
list(set(lst_link))
# Out:
# ['/wiki/Data_science',
#  '/wiki/Database',
#  '/wiki/Pytorch',
#  '/wiki/Data_scraping',
#  '/wiki/File:Kernel_Machine.svg',
#  '/wiki/Wikipedia:Contents',
#  '/wiki/Statistics',
#  '/wiki/Peter_Naur',
#  '/wiki/Help:Contents',
#  '/wiki/T-distributed_stochastic_neighbor_embedding',
#  '/wiki/Empirical_risk_minimization',
#  '/wiki/Data_preservation',
#  '/wiki/Wikipedia:File_Upload_Wizard',
#  '/wiki/Q-learning',
#  '/wiki/Committee_on_Data_for_Science_and_Technology',
#  '/wiki/Montpellier_2_University',
#  '/wiki/C.F._Jeff_Wu',
#  '/wiki/Naive_Bayes_classifier',
#  '/wiki/Non-negative_matrix_factorization',
#  '/wiki/Human%E2%80%93computer_interaction',
#  '/wiki/Knowledge',
#  '/wiki/Journal_of_Machine_Learning_Research',
#  '/wiki/Template_talk:Data',
#  '/wiki/Hierarchical_clustering',
#  '/wiki/Special:WhatLinksHere/Data_science',
#  '/wiki/Autoencoder',
#  '/wiki/Data_storage',
#  '/wiki/Data_analysis',
#  '/wiki/Ensemble_learning',
#  '/wiki/Decision_tree_learning',
# ...

# %%
# using href=True
source.find_all('a', href=True)
links = list(set([item['href'] for item in source.find_all('a', href=True)]))
links
# Out:
# ['/wiki/Database',
#  'http://www2.isye.gatech.edu/~jeffwu/presentations/datascience.pdf',
#  '/wiki/Data_scraping',
#  '#cite_note-8',
#  '/wiki/Statistics',
#  'https://web.archive.org/web/20141109113411/http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext',
#  'http://courses.csail.mit.edu/18.337/2015/docs/50YearsDataScience.pdf',
#  '/w/index.php?title=Data_science&action=history',
#  '#cite_ref-1',
#  '#cite_note-9',
#  '/wiki/Data_preservation',
#  '/wiki/Q-learning',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'https://www.datasciencecentral.com/profiles/blogs/data-science-without-statistics-is-possible-even-desirable',
#  '/wiki/C.F._Jeff_Wu',
#  '/w/index.php?title=Data_science&oldid=962714125',
#  '/wiki/Special:WhatLinksHere/Data_science',
#  '/wiki/Data_storage',
#  '/wiki/Decision_tree_learning',
#  '/wiki/Data_archaeology',
#  'https://www.wired.com/2014/07/a-drag-and-drop-toolkit-that-lets-anyone-create-interactive-maps/',
# ...

# %% [markdown]
# ### Step 3: Use list comprehensions with conditions to clean the link list.
#
# There are two types of links, absolute and relative. Absolute links have the full URL and begin with *http* while relative links begin with a forward slash (/) and point to an internal page within the *wikipedia.org* domain. Clean the respective types of URLs as follows.
#
# - Absolute Links: Create a list of these and remove any that contain a percentage sign (%).
# - Relative Links: Create a list of these, add the domain to the link so that you have the full URL, and remove any that contain a percentage sign (%).
# - Combine the list of absolute and relative links and ensure there are no duplicates.

# %%
domain = 'http://wikipedia.org'

# %%
lst_absolute_links = [link for link in links if (link.startswith('http')) and ('%' not in link)]
lst_absolute_links
# Out:
# ['http://www2.isye.gatech.edu/~jeffwu/presentations/datascience.pdf',
#  'https://web.archive.org/web/20141109113411/http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext',
#  'http://courses.csail.mit.edu/18.337/2015/docs/50YearsDataScience.pdf',
#  'https://www.datasciencecentral.com/profiles/blogs/data-science-without-statistics-is-possible-even-desirable',
#  'https://www.wired.com/2014/07/a-drag-and-drop-toolkit-that-lets-anyone-create-interactive-maps/',
#  'https://www.nsf.gov/pubs/2005/nsb0540/',
#  'https://www.northeastern.edu/graduate/blog/data-science-careers-shaping-our-future/',
#  'https://www.statisticsviews.com/details/feature/5133141/Nate-Silver-What-I-need-from-statisticians.html',
#  'https://fi.wikipedia.org/wiki/Datatiede',
#  'https://medriscoll.com/post/4740157098/the-three-sexy-skills-of-data-geeks',
#  'https://en.wikipedia.org/w/index.php?title=Data_science&oldid=962714125',
# ...

# %%
lst_relative_links = [domain + link for link in links if (link.startswith('/')) and ('%' not in link)]
lst_relative_links
# Out:
# ['http://wikipedia.org/wiki/Database',
#  'http://wikipedia.org/wiki/Data_scraping',
#  'http://wikipedia.org/wiki/Statistics',
#  'http://wikipedia.org/w/index.php?title=Data_science&action=history',
#  'http://wikipedia.org/wiki/Data_preservation',
#  'http://wikipedia.org/wiki/Q-learning',
#  'http://wikipedia.org//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'http://wikipedia.org/wiki/C.F._Jeff_Wu',
#  'http://wikipedia.org/w/index.php?title=Data_science&oldid=962714125',
#  'http://wikipedia.org/wiki/Special:WhatLinksHere/Data_science',
#  'http://wikipedia.org/wiki/Data_storage',
#  'http://wikipedia.org/wiki/Decision_tree_learning',
#  'http://wikipedia.org/wiki/Data_archaeology',
#  'http://wikipedia.org/wiki/Machine_learning',
#  'http://wikipedia.org/wiki/ISSN_(identifier)',
#  'http://wikipedia.org/wiki/Domain_knowledge',
#  'http://wikipedia.org/wiki/Conditional_random_field',
#  'http://wikipedia.org/wiki/Category:CS1_maint:_date_and_year',
# ...

# %%
combined_links = list(set(lst_absolute_links + lst_relative_links))
combined_links
# Out:
# ['http://wikipedia.org/wiki/Special:BookSources/978-0-9825442-0-4',
#  'http://www2.isye.gatech.edu/~jeffwu/presentations/datascience.pdf',
#  'http://wikipedia.org/wiki/Support-vector_machine',
#  'https://web.archive.org/web/20141109113411/http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext',
#  'http://courses.csail.mit.edu/18.337/2015/docs/50YearsDataScience.pdf',
#  'http://wikipedia.org/wiki/Linear_discriminant_analysis',
#  'http://wikipedia.org/w/index.php?title=Data_science&action=edit&section=2',
#  'http://wikipedia.org/wiki/Statistical_learning_theory',
#  'http://wikipedia.org/wiki/Extract,_transform,_load',
#  'http://wikipedia.org/wiki/Convolutional_neural_network',
#  'http://wikipedia.org/wiki/C.F._Jeff_Wu',
#  'http://wikipedia.org/wiki/Artificial_neural_network',
#  'http://wikipedia.org/wiki/Data_preservation',
#  'https://eu.wikipedia.org/wiki/Datu_zientzia',
#  'http://wikipedia.org/wiki/Wikipedia:General_disclaimer',
# ...

# %% [markdown]
# ### Step 4: Use the os library to create a folder called *wikipedia* and make that the current working directory.

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\[DATA_PYTHON]\\( 2020 JUN DATA FT )\\Week 04_Day3_a_Parallelization\\your-code'

# %%
# Directory
directory = "wikipedia"

# Parent Directory path (current path) 
parent_dir = os.getcwd()
    
# Path  
path = os.path.join(parent_dir, directory)  
print(path)

if not os.path.exists(path):
    os.mkdir(path)
    print(f"Directory {directory} created") 
else:
    print(f"Directory {directory} already exists")
# Out:
# D:\[DATA_PYTHON]\( 2020 JUN DATA FT )\Week 04_Day3_a_Parallelization\your-code\wikipedia
# Directory wikipedia already exists

# %% [markdown]
# ### Step 5: Write a function called index_page that accepts a link and does the following.
#
# - Tries to request the content of the page referenced by that link.
# - Slugifies the filename using the `slugify` function from the [python-slugify](https://pypi.org/project/python-slugify/) library and adds a .html file extension.
#     - If you don't already have the python-slugify library installed, you can pip install it as follows: `$ pip3 install python-slugify`.
#     - To import the slugify function, you would do the following: `from slugify import slugify`.
#     - You can then slugify a link as follows `slugify(link)`.
# - Creates a file in the wikipedia folder using the slugified filename and writes the contents of the page to the file.
# - If an exception occurs during the process above, just `pass`.

# %%
#!pip install python-slugify

# %%
from slugify import slugify

# %%
# sample of slugifies the filename
slugify('http://wikipedia.org/wiki/Jeffrey_T._Leek')
# Out:
# 'http-wikipedia-org-wiki-jeffrey-t-leek'

# %%
os.chdir(path)
os.getcwd()
# Out:
# 'D:\\[DATA_PYTHON]\\( 2020 JUN DATA FT )\\Week 04_Day3_a_Parallelization\\your-code\\wikipedia'

# %%
def index_page(link):
    import requests
    from slugify import slugify
    
    try:
        contents = requests.get(link).content
        # Slugfies filename and add a .html file extension 
        filename = slugify(link)+".html"
        
        with open(filename, "wb") as f:
            f.write(contents)
    except:
        pass

# %% [markdown]
# ### Step 6: Sequentially loop through the list of links, running the index_page function each time.
#
# Remember to include `%%time` at the beginning of the cell so that it measures the time it takes for the cell to run.
#
# _hint: Use tqdm to keep track of the time._

# %%
from tqdm.auto import tqdm

# %%
#%%time
#for link in tqdm(combined_links):
#    index_page(link)

# %% [markdown]
# ### Step 7: Perform the page indexing in parallel and note the difference in performance.
#
# Remember to include `%%time` at the beginning of the cell so that it measures the time it takes for the cell to run.
#
# Use both methods, i.e., for one hand use the `multiprocess` module to use the function created in the jupyter notebook and run the download in parallel.
#
# And for another hand create a python file containing the function to download the file and use the `multiprocessing` module to run.

# %%
from multiprocess import Pool,cpu_count
cpu_count()
# Out:
# 6

# %%
pool = Pool(processes = cpu_count())

# %%
#%%time

#result = pool.map(index_page,combined_links)

# %%
#pool.terminate()

# %% [markdown]
# **BONUS**: Create a function that counts how many files are there in the wikipedia folder using the `os` module.
#
# Delete the files from the folder before you run and perform the above solution asynchronously.
#
# Use your function to check how many files are being downloaded.

# %%
print(path)

# %%
result = pool.map_async(index_page,combined_links)
# result.get()

# %%
num_files = len([f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))])
num_files
# Out:
# 109

# %%
# count # of files in the wikipedia folder

print(len(os.listdir(path)))
# Out:
# 228

# %%
os.remove(path)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-56-4a9912409958> in <module>
# ----> 1 os.remove(path)
#
# PermissionError: [WinError 5] Acesso negado: 'D:\\[DATA_PYTHON]\\( 2020 JUN DATA FT )\\Week 04_Day3_a_Parallelization\\your-code\\wikipedia'

# %%
# result.get() # []

# %%
path
# Out:
# 'D:\\[DATA_PYTHON]\\( 2020 JUN DATA FT )\\Week 04_Day3_a_Parallelization\\your-code\\wikipedia'
