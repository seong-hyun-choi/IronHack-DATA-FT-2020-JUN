# %% [markdown]
# # Pandas: Importing and Exporting

# %%
import os

# %% [markdown]
# ## IMPORTING AND EXPORTING DELIMITED FILES

# %% [markdown]
# ### Comma separated values (CSV) files
#
# A file that is separated (or delimited) by commas (or anything else)

# %% [markdown]
# Example:
#
# **-- comma separated file --**
#
#     name,year,value
#     Andre,2020,100
#     Fernanda,1900,1
#
# **-- tab separated file --**
#
#     name    year    value
#     Andre    2020    100
#     Fernanda    1900    1
#
# **-- tab separated file (another way) --**
#
#     name\tyear\tvalue
#     Andre\t2020\t100
#     Fernanda\t1900\t1
#
# **-- hash separated file --**
#
#     name#year#value
#     Andre#2020#100
#     Fernanda#1900#1
#
# **-- pipe separated file --**
#
#     name|year|value
#     Andre|2020|100
#     Fernanda|1900|1
#
#     ...

# %% [markdown]
# ### Import comma-separated variable file (the default)

# %%
import pandas as pd

# %%
pwd
# Out:
# 'D:\\[DATA_PYTHON]\\( 2020 JUN DATA FT )\\Week 02_Day2_b_Importing and Exporting Data'

# %%
pd.read_csv('data/vehicles')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-e8bf73399ad5> in <module>
# ----> 1 pd.read_csv('data/vehicles')
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File data/vehicles does not exist: 'data/vehicles'

# %%
df = pd.read_csv('../data/vehicles.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-42549bf75df0> in <module>
# ----> 1 df = pd.read_csv('../data/vehicles.csv')
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../data/vehicles.csv does not exist: '../data/vehicles.csv'

# %%
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
df.head(2)
# Out:
#          Make              Model  Year  Engine Displacement  Cylinders  \
# 0  AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General   FJ8c Post Office  1984                  4.2        6.0
#
#       Transmission     Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550

# %%
df.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# min        6.000000      9.000000      7.000000                37.000000
# 25%       15.000000     20.000000     16.000000               395.000000
# 50%       17.000000     24.000000     19.000000               467.736842
# 75%       20.000000     27.000000     23.000000               555.437500
# max       58.000000     61.000000     56.000000              1269.571429
#
#        Fuel Cost/Year
# count    35952.000000
# mean      1892.598465
# std        506.958627
# min        600.000000
# 25%       1500.000000
# 50%       1850.000000
# 75%       2200.000000
# max       5800.000000

# %%
# !pwd
# Out:
# /c/Users/andreaguiar/Desktop/usr/dev/ironhack/ft202006/classes/week2/4_Pandas_Import_Export

# %%
# absolute path
pd.read_csv('/Users/andreaguiar/Desktop/usr/dev/ironhack/ft202002/classes/week2/4_Pandas_Import_Export')

# %%
# relative path
pd.read_csv('data/vehicles.csv')

# %% [markdown]
# In this way, the `pd.read_csv()` method is just outputing the results on screen.
#
# If I wanted to store it in a variable I would have to **assign** this result into a variable

# %%
vehicles = pd.read_csv('data/vehicles.csv')

# %% [markdown]
# ## Import tab-delimited file

# %%
pd.read_csv('data/vehicles_tab.txt', sep='\t')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
print('\tb\n\ta')
# Out:
# 	b
# 	a

# %%
pd.read_csv('data/vehicles_tab.txt', sep='\t')

# %% [markdown]
# ## Import pipe delimited file

# %%
df = pd.read_csv('data/vehicles_pipe.txt', sep='|')
df.head()

# %%
# hash
df = pd.read_csv('data/vehicles_hash.txt', sep='#')
df.head()

# %% [markdown]
# # Importing Excel FIles

# %%
pd.read_excel('data/vehicles.xlsx')

# %%
aldrey_treated = pd.read_excel('data/dados_artigo1.xlsx', header=1, skiprows=[2,3], usecols='B:M')

# %%
aldrey_treated

# %% [markdown]
# ## Read from specific excel sheet

# %%
df = pd.read_excel('data/dados_artigo1.xlsx', sheet_name='dataset')
df.head()

# %% [markdown]
# # Exporting datasets

# %% [markdown]
# ## Export TO EXCEL

# %%
aldrey_treated.to_excel('data/aldrey_treated.xlsx', sheet_name='treated')

# %%
test = aldrey_treated*10

# %%
# this overrides the file
test.to_excel('data/aldrey_treated.xlsx', sheet_name='treated_10')

# %% [markdown]
# ## BONUS: Saving to multiple sheets

# %%
writer = pd.ExcelWriter('data/aldrey_treated2.xlsx', engine = 'openpyxl')

# %%
aldrey_treated.to_excel(writer, sheet_name='treated')
test.to_excel(writer, sheet_name='treated_10')

# %%
writer.save()
writer.close()

# %% [markdown]
# ## Export TO CSV

# %%
df.head()

# %%
df.to_csv('data/exported_file_v1.csv', index=False)

# %%
pd.read_csv('data/exported_file_v1.csv')

# %%
# pd.read_csv('data/exported_file_v2.csv', index_col=0)

# %% [markdown]
# **NOTE**: If you do not specify the argument `index=False`, the output in the csv file will create an unnamed index column with the *dataframe indexes*.

# %%
df.to_csv('data/exported_file.csv', index=False)

# %% [markdown]
# ## Export to csv using a specific separator

# %% [markdown]
# ### Semicolon

# %%
df.to_csv('data/exported_file_semicolon.csv', index=False, sep=';')

# %% [markdown]
# ### Pipe

# %%
df.to_csv('data/exported_file_pipe.csv', index=False, sep='|')

# %% [markdown]
# ### plust or minus

# %%
df.to_csv('data/exported_file_plusminus.csv', index=False, sep='±')

# %% [markdown]
# # Import and export JSON files

# %% [markdown]
# What is a JSON file?

# %% [markdown]
# JSON 1:
# ```json
# { "name":"John", "age":30, "car":null }
# ```
#
# JSON 2:
# ```json
# {"students":[
#    {"name":"Andre", "age":23, "state":"SP"},
#    {"name":"Rafael", "age":28, "state":"RJ"},
#    {"name":"Claudia", "age":32, "state":"PA"},
#    {"name":"Lajos", "age":28, "state":"MA"}
# ]}
# ```

# %%
pd.read_json('data/vehicles.json')

# %%
data.head()

# %% [markdown]
# For a JSON file, you can have different `orient` options.
#
# `'split'`: Dictionary containing indexes, columns, and data.
#
# `'index'`: Nested dictionaries containing {index:{column:value}}.
#
# `'columns'`: Nested dictionaries containing {column:{index:value}}
#
# `'values'`: Nested list where each sublist contains the values for a record.
#
# `'table'`: Nested dictionaries containing schema and data (records).

# %%
data.sample(10)

# %%
data.sample(10).to_json('data/vehicles_split.json', orient='split')
data.sample(10).to_json('data/vehicles_index.json', orient='index')
data.sample(10).to_json('data/vehicles_columns.json', orient='columns')
data.sample(10).to_json('data/vehicles_values.json', orient='values')
data.sample(10).to_json('data/vehicles_table.json', orient='table')

# %%
pd.read_json('data/vehicles_values.json', orient='values')

# %%
data.sample(10)

# %% [markdown]
# ## Encoding

# %%
df = data.head(12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a264a3c1f8c9> in <module>
# ----> 1 df = data.head(12)
#
# NameError: name 'data' is not defined

# %%
#df.to_csv('data/teste.csv')

# %%
pd.read_csv('data/CSV.8859-1.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe1 in position 1: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-19-0792fe2a15f8> in <module>
# ----> 1 pd.read_csv('data/CSV.8859-1.csv')
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe1 in position 1: invalid continuation byte

# %%
pd.read_csv('data/CSV.8859-1.csv', encoding='latin-1', sep=';').sample(20)
# Out:
#           Data       Projeto(s)    Ini    Ter  Horas  \
# 90  ter, 28/01               RS  16:00  16:30  00:30
# 76  qui, 23/01          PRODESP  14:00  15:30  01:30
# 70  qua, 22/01          PRODESP  13:30  16:00  02:30
# 43  qua, 15/01          PRODESP  11:30  12:00  00:30
# 61  seg, 20/01               RS  13:30  15:00  01:30
# 65  ter, 21/01              GTE  12:30  13:30  01:00
# 24  qui, 09/01               RS  13:30  14:30  01:00
# 16  ter, 07/01  GTE - Orçamento  15:30  17:30  02:00
# 83  dom, 26/01          PRODESP  14:00  17:00  03:00
# 82  sex, 24/01          PRODESP  15:30  18:00  02:30
# 77  qui, 23/01           DETRAN  15:30  16:30  01:00
# 14  ter, 07/01        GTE - Git  13:30  14:00  00:30
# 5   qui, 02/01               RS  15:30  16:00  00:30
# 74  qui, 23/01          PRODESP  10:00  12:00  02:00
# 79  sex, 24/01       Paulistana  10:00  11:00  01:00
# 20  qua, 08/01         GTE - FC  15:30  18:00  02:30
# 57  sáb, 18/01          PRODESP  22:30  00:00  01:30
# 86  seg, 27/01               RS  14:00  16:00  02:00
# 18  qua, 08/01         GTE - FC  10:30  12:00  01:30
# 95  sex, 31/01               RS  10:30  12:00  01:30
#
#                             Atividade  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 90    Automatização da extração Inova         NaN         NaN         NaN
# 76                     Sistemas APESP         NaN         NaN         NaN
# 70                     Sistemas APESP         NaN         NaN         NaN
# 43  Sistema APESP - ambiente Maurício         NaN         NaN         NaN
# 61                     Extração Inova         NaN         NaN         NaN
# 65         Atividades administrativas         NaN         NaN         NaN
# 24               Bug na extação Inova         NaN         NaN         NaN
# 16    Estudo para módulo orçamentário         NaN         NaN         NaN
# 83                     Sistemas APESP         NaN         NaN         NaN
# 82                     Sistemas APESP         NaN         NaN         NaN
# 77           Contratação Theme Forest         NaN         NaN         NaN
# 14                       Workshop Git         NaN         NaN         NaN
# 5                      Extração Inova         NaN         NaN         NaN
# 74                     Sistemas APESP         NaN         NaN         NaN
# 79         Relatório de monitoramento         NaN         NaN         NaN
# 20          Compilação das pendências         NaN         NaN         NaN
# 57                Merge Sistema APESP         NaN         NaN         NaN
# 86                      Reunião CITEM         NaN         NaN         NaN
# 18    Estudo para módulo orçamentário         NaN         NaN         NaN
# 95                Revisão query Inova         NaN         NaN         NaN
#
#     Unnamed: 9
# 90         NaN
# 76         NaN
# 70         NaN
# 43         NaN
# 61         NaN
# 65         NaN
# 24         NaN
# 16         NaN
# 83         NaN
# 82         NaN
# 77         NaN
# 14         NaN
# 5          NaN
# 74         NaN
# 79         NaN
# 20         NaN
# 57         NaN
# 86         NaN
# 18         NaN
# 95         NaN

# %%
pd.read_csv('data/CSV.UTF8.csv', sep=';').sample(20)
# Out:
#           Data  Projeto(s)    Ini    Ter  Horas  \
# 79  sex, 24/01  Paulistana  10:00  11:00  01:00
# 58  dom, 19/01     PRODESP  02:30  12:00  09:30
# 14  ter, 07/01   GTE - Git  13:30  14:00  00:30
# 83  dom, 26/01     PRODESP  14:00  17:00  03:00
# 75  qui, 23/01          RS  13:30  14:00  00:30
# 37  ter, 14/01  Paulistana  13:30  14:00  00:30
# 3   qui, 02/01    GTE - FC  14:00  15:00  01:00
# 64  ter, 21/01     PRODESP  11:00  11:30  00:30
# 71  qua, 22/01  Paulistana  16:00  16:30  00:30
# 2   qui, 02/01         GTE  13:30  14:00  00:30
# 4   qui, 02/01         GTE  15:00  15:30  00:30
# 54  sex, 17/01     PRODESP  14:30  15:00  00:30
# 48  qui, 16/01  Paulistana  13:00  14:30  01:30
# 6   sex, 03/01          RS  10:00  12:00  02:00
# 42  qua, 15/01     PRODESP  10:30  11:30  01:00
# 51  qui, 16/01     PRODESP  16:30  17:00  00:30
# 15  ter, 07/01     PRODESP  14:00  15:30  01:30
# 82  sex, 24/01     PRODESP  15:30  18:00  02:30
# 27  qui, 09/01  Paulistana  16:00  18:30  02:30
# 31  seg, 13/01  Paulistana  17:00  19:00  02:00
#
#                               Atividade  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 79           Relatório de monitoramento         NaN         NaN         NaN
# 58                       Sistemas APESP         NaN         NaN         NaN
# 14                         Workshop Git         NaN         NaN         NaN
# 83                       Sistemas APESP         NaN         NaN         NaN
# 75  Sobre a extração da terceira edição         NaN         NaN         NaN
# 37           Relatório de monitoramento         NaN         NaN         NaN
# 3   Troubleshooting Contrato X Rubricas         NaN         NaN         NaN
# 64                       Sistemas APESP         NaN         NaN         NaN
# 71              Atualização de ambiente         NaN         NaN         NaN
# 2               Tarefas administrativas         NaN         NaN         NaN
# 4               Tarefas administrativas         NaN         NaN         NaN
# 54                         Alinhamentos         NaN         NaN         NaN
# 48                    Atividades gerais         NaN         NaN         NaN
# 6                        Extração Inova         NaN         NaN         NaN
# 42                       Sistemas APESP         NaN         NaN         NaN
# 51                Ajuda a desenvolvedor         NaN         NaN         NaN
# 15               Planilhas de convênios         NaN         NaN         NaN
# 82                       Sistemas APESP         NaN         NaN         NaN
# 27           Relatório de monitoramento         NaN         NaN         NaN
# 31          Performance das plataformas         NaN         NaN         NaN
#
#     Unnamed: 9
# 79         NaN
# 58         NaN
# 14         NaN
# 83         NaN
# 75         NaN
# 37         NaN
# 3          NaN
# 64         NaN
# 71         NaN
# 2          NaN
# 4          NaN
# 54         NaN
# 48         NaN
# 6          NaN
# 42         NaN
# 51         NaN
# 15         NaN
# 82         NaN
# 27         NaN
# 31         NaN

# %% [markdown]
# # Importing files from URLs

# %% [markdown]
# Example: https://github.com/rfordatascience/tidytuesday

# %%
pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-06-09/firsts.csv')
# Out:
#      year                                     accomplishment  \
# 0    1738              First free African-American community
# 1    1760      First known African-American published author
# 2    1768  First known African-American to be elected to ...
# 3    1773  First known African-American woman to publish ...
# 4    1773             First separate African-American church
# ..    ...                                                ...
# 474  2019  First African-American to win an Academy Award...
# 475  2019  First member of the British royal family of Af...
# 476  2019  First African-American secretary of the Smiths...
# 477  2019  First African-American female director of an A...
# 478  2019  First African-American full-time curator at th...
#
#                                                 person  \
# 0    Gracia Real de Santa Teresa de Mose (later nam...
# 1              Jupiter Hammon (poem An Evening Thought
# 2    Wentworth Cheswell, town constable in Newmarke...
# 3    Phillis Wheatley (Poems on Various Subjects, R...
# 4    Silver Bluff Baptist Church, Aiken County, Sou...
# ..                                                 ...
# 474            Hannah Beachler for Black Panther [253]
# 475                         Archie Mountbatten-Windsor
# 476                                       Lonnie Bunch
# 477                                 Denise Verret[254]
# 478                                 Ashley James.[255]
#
#                              gender              category
# 0           African-American Firsts         Social & Jobs
# 1    Female African American Firsts  Arts & Entertainment
# 2           African-American Firsts         Social & Jobs
# 3    Female African American Firsts  Arts & Entertainment
# 4           African-American Firsts              Religion
# ..                              ...                   ...
# 474         African-American Firsts  Arts & Entertainment
# 475         African-American Firsts         Social & Jobs
# 476         African-American Firsts  Arts & Entertainment
# 477  Female African American Firsts  Arts & Entertainment
# 478         African-American Firsts  Arts & Entertainment
#
# [479 rows x 5 columns]

# %%
af = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-06-09/firsts.csv')

# %%
af.head()
# Out:
#    year                                     accomplishment  \
# 0  1738              First free African-American community
# 1  1760      First known African-American published author
# 2  1768  First known African-American to be elected to ...
# 3  1773  First known African-American woman to publish ...
# 4  1773             First separate African-American church
#
#                                               person  \
# 0  Gracia Real de Santa Teresa de Mose (later nam...
# 1            Jupiter Hammon (poem An Evening Thought
# 2  Wentworth Cheswell, town constable in Newmarke...
# 3  Phillis Wheatley (Poems on Various Subjects, R...
# 4  Silver Bluff Baptist Church, Aiken County, Sou...
#
#                            gender              category
# 0         African-American Firsts         Social & Jobs
# 1  Female African American Firsts  Arts & Entertainment
# 2         African-American Firsts         Social & Jobs
# 3  Female African American Firsts  Arts & Entertainment
# 4         African-American Firsts              Religion
