# %% [markdown]
# # Pandas: Importing and Exporting

# %%
import os

# %% [markdown]
# ## IMPORTING AND EXPORTING DELIMITED FILES

# %% [markdown]
# ### Comma separated values (CSV) files
#
# A file that is separated (or delimited) by commas (or anything else)

# %% [markdown]
# Example:
#
# **-- comma separated file --**
#
#     name,year,value
#     Andre,2020,100
#     Fernanda,1900,1
#
# **-- tab separated file --**
#
#     name    year    value
#     Andre    2020    100
#     Fernanda    1900    1
#
# **-- tab separated file (another way) --**
#
#     name\tyear\tvalue
#     Andre\t2020\t100
#     Fernanda\t1900\t1
#
# **-- hash separated file --**
#
#     name#year#value
#     Andre#2020#100
#     Fernanda#1900#1
#
# **-- pipe separated file --**
#
#     name|year|value
#     Andre|2020|100
#     Fernanda|1900|1
#
#     ...

# %% [markdown]
# ### Import comma-separated file (the default)

# %%
import pandas as pd

# %%
# !pwd
# Out:
# /c/Users/andreaguiar/Desktop/usr/dev/ironhack/ft202006/classes/week2/4_Pandas_Import_Export

# %%
# !ls
# Out:
# data
# data copy
# import-export-pandas.ipynb
# import-export-pandas-original.ipynb
# import-export-pandas-v_original.ipynb
# vehicles_import.zip

# %%
pd.read_csv('data/vehicles.csv')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
banana = pd.read_csv('data/vehicles.csv')

# %%
banana
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
df = pd.read_csv('data/vehicles.csv')

# %%
df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
df.head(2)
# Out:
#          Make              Model  Year  Engine Displacement  Cylinders  \
# 0  AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General   FJ8c Post Office  1984                  4.2        6.0
#
#       Transmission     Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550

# %%
df.tail()
# Out:
#         Make         Model  Year  Engine Displacement  Cylinders  \
# 35947  smart  fortwo coupe  2013                  1.0        3.0
# 35948  smart  fortwo coupe  2014                  1.0        3.0
# 35949  smart  fortwo coupe  2015                  1.0        3.0
# 35950  smart  fortwo coupe  2016                  0.9        3.0
# 35951  smart  fortwo coupe  2016                  0.9        3.0
#
#        Transmission        Drivetrain Vehicle Class Fuel Type  \
# 35947     Auto(AM5)  Rear-Wheel Drive   Two Seaters   Premium
# 35948     Auto(AM5)  Rear-Wheel Drive   Two Seaters   Premium
# 35949     Auto(AM5)  Rear-Wheel Drive   Two Seaters   Premium
# 35950     Auto(AM6)  Rear-Wheel Drive   Two Seaters   Premium
# 35951  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 35947           9.155833        34           38            36
# 35948           9.155833        34           38            36
# 35949           9.155833        34           38            36
# 35950           9.155833        34           39            36
# 35951           9.417429        32           39            35
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 35947                    244.0            1100
# 35948                    243.0            1100
# 35949                    244.0            1100
# 35950                    246.0            1100
# 35951                    255.0            1150

# %%
df.tail(2)
# Out:
#         Make         Model  Year  Engine Displacement  Cylinders  \
# 35950  smart  fortwo coupe  2016                  0.9        3.0
# 35951  smart  fortwo coupe  2016                  0.9        3.0
#
#        Transmission        Drivetrain Vehicle Class Fuel Type  \
# 35950     Auto(AM6)  Rear-Wheel Drive   Two Seaters   Premium
# 35951  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 35950           9.155833        34           39            36
# 35951           9.417429        32           39            35
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 35950                    246.0            1100
# 35951                    255.0            1150

# %%
df.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# min        6.000000      9.000000      7.000000                37.000000
# 25%       15.000000     20.000000     16.000000               395.000000
# 50%       17.000000     24.000000     19.000000               467.736842
# 75%       20.000000     27.000000     23.000000               555.437500
# max       58.000000     61.000000     56.000000              1269.571429
#
#        Fuel Cost/Year
# count    35952.000000
# mean      1892.598465
# std        506.958627
# min        600.000000
# 25%       1500.000000
# 50%       1850.000000
# 75%       2200.000000
# max       5800.000000

# %%
# relative path
pd.read_csv('data/vehicles.csv')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
# !pwd
# Out:
# /c/Users/andreaguiar/Desktop/usr/dev/ironhack/ft202006/classes/week2/4_Pandas_Import_Export

# %%
# absolute path
pd.read_csv('/Users/andreaguiar/Desktop/usr/dev/ironhack/ft202002/classes/week2/4_Pandas_Import_Export/data/vehicles.csv')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# In this way, the `pd.read_csv()` method is just outputing the results on screen.
#
# If I wanted to store it in a variable I would have to **assign** this result into a variable

# %%
pd.read_csv('data/vehicles.csv').head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
vehicles = pd.read_csv('data/vehicles.csv')

# %% [markdown]
# ## Import tab-delimited file

# %%
pd.read_csv('data/vehicles_tab.txt')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-60-e5a6f00df215> in <module>
# ----> 1 pd.read_csv('data/vehicles_tab.txt')
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 4319, saw 2

# %%
pd.read_csv('data/vehicles_tab.txt', sep='\t')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
print('\tb\n\t\ta')
# Out:
# 	b
# 		a

# %%
df = pd.read_csv('data/vehicles_tab.txt', sep='\t')

# %%
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# ## Import pipe delimited file

# %%
df = pd.read_csv('data/vehicles_pipe.txt')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-69-dd408e291a91> in <module>
# ----> 1 df = pd.read_csv('data/vehicles_pipe.txt')
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 4319, saw 2

# %%
df = pd.read_csv('data/vehicles_pipe.txt', sep='|')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# ## Import hash delimited file

# %%
# hash
df = pd.read_csv('data/vehicles_hash.txt', sep='#')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# # Importing Excel Files

# %%
pd.read_csv('data/vehicles.xlsx')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-75-2be5556b8fac> in <module>
# ----> 1 pd.read_csv('data/vehicles.xlsx')
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 0-1: invalid continuation byte

# %%
# !pip install xlrd

# %%
pd.read_excel('data/vehicles.xlsx')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0              4  Automatic 3-spd     2-Wheel Drive
# 1              6  Automatic 3-spd     2-Wheel Drive
# 2              4  Automatic 3-spd  Rear-Wheel Drive
# 3              6  Automatic 3-spd  Rear-Wheel Drive
# 4              6  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947          3        Auto(AM5)  Rear-Wheel Drive
# 35948          3        Auto(AM5)  Rear-Wheel Drive
# 35949          3        Auto(AM5)  Rear-Wheel Drive
# 35950          3        Auto(AM6)  Rear-Wheel Drive
# 35951          3     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
pd.read_excel('data/dados_artigo1.xlsx', 
              sheet_name='PT', 
              skiprows=[0, 2, 3, 33,34,35],
              usecols='B:M')
# Out:
#     C1 Entrada  T1 Entrada  C1 Saída  T1 Saída  C2 Entrada  T2 Entrada  \
# 0        0.274       0.234     0.370     0.126       0.232       0.244
# 1        0.179       0.159     0.366     0.376       0.167       0.152
# 2        1.852       3.072     0.342     0.236       1.627       1.852
# 3        1.042       1.087     0.178     0.103       1.099       1.317
# 4        0.247       0.224     0.162     0.108       0.249       0.264
# 5        1.037       1.982     0.176     0.030       1.037       1.982
# 6        0.699       0.849     0.294     0.123       0.739       0.747
# 7        0.264       0.279     0.228     0.126       0.232       0.252
# 8        0.532       0.557     0.243     0.065       0.607       2.107
# 9        0.069       0.113     0.017     0.014       0.063       0.066
# 10       2.883      13.923     1.023     0.399       2.103       3.168
# 11       2.313       3.648     1.047     0.263       2.343       5.973
# 12       0.423       0.438     1.426     0.171       0.461       0.386
# 13       2.216       3.858     0.918     0.369       2.336       4.331
# 14       4.691       4.721     1.039     0.468       4.758       4.811
# 15       4.391       4.323     0.888     0.827       4.593       4.503
# 16       7.421       7.466     0.583     0.056       6.746       7.503
# 17       0.483       0.476     0.425     0.071       0.551       0.498
# 18       0.573       0.858     0.297     0.525       0.633       0.618
# 19       0.596       0.678     0.185     0.554       0.596       0.633
# 20       0.612       0.605     0.564     0.218       0.552       0.552
# 21       1.490       1.385     0.747     0.000       1.460       1.430
# 22       0.905       0.890     0.903     0.301       0.965       0.875
# 23       1.925       1.850     0.710     0.173       1.760       2.052
# 24       1.842       1.985     0.639     0.255       1.850       1.752
# 25       0.560       0.507     0.878     0.261       1.115       0.132
# 26       0.324       0.444     0.232     0.072       0.311       0.324
# 27       0.389       0.499     0.157     0.000       0.341       0.536
# 28       0.206       0.204     0.185     0.000       0.214       0.214
#
#     C2 Saída  T2 Saída  C3 Entrada  T3 Entrada  C3 Saída  T3 Saída
# 0      0.065     0.088       0.227       0.227     0.087     0.088
# 1      0.100     0.146       0.169       0.202     0.135     0.077
# 2      0.196     0.187       3.327       1.699     0.206     0.228
# 3      0.173     0.045       1.747       1.124     0.125     0.068
# 4      0.155     0.065       0.234       0.242     0.155     0.060
# 5      0.032     0.000       1.037       1.982     0.062     0.000
# 6      0.273     0.057       0.689       0.692     0.143     0.035
# 7      0.173     0.024       0.234       0.227     0.102     0.050
# 8      0.226     0.042       0.739       1.017     0.102     0.050
# 9      0.053     0.000       0.062       0.063     0.012     0.001
# 10     0.887     0.117       1.788       1.721     0.464     0.132
# 11     0.911     0.026       2.748       2.628     0.321     0.003
# 12     0.927     0.072       0.438       0.423     0.434     0.102
# 13     0.532     0.171       2.471       1.998     0.669     0.163
# 14     0.661     0.468       4.976       4.863     0.774     0.186
# 15     0.585     0.171       5.111       6.281     0.427     0.095
# 16     0.659     0.192       7.001       7.376     0.335     0.033
# 17     0.629     0.086       0.491       0.536     0.365     0.033
# 18     0.591     0.291       0.911       0.573     0.365     0.101
# 19     0.427     0.133       0.558       0.566     0.321     0.363
# 20     0.769     0.142       0.537       0.567     0.988     0.104
# 21     0.656     0.571       1.460       1.475     0.000     0.112
# 22     0.601     0.149       0.935       1.752     0.586     0.195
# 23     0.672     0.043       2.322       2.195     0.551     0.066
# 24     0.480     0.233       1.887       1.760     0.692     0.149
# 25     0.689     0.541       1.137       0.552     0.742     0.156
# 26     0.104     0.000       0.329       0.639     0.000     0.000
# 27     0.190     0.000       0.386       0.421     0.000     0.000
# 28     0.000     0.000       0.211       0.216     0.000     0.000

# %% [markdown]
# ## Extra: merged cells

# %%
my_col_name = pd.read_excel('data/dados_artigo1.xlsx', sheet_name='PT', usecols='O:T').columns[0]
my_col_name
# Out:
# 'Porc_remocao'

# %%
df = pd.read_excel('data/dados_artigo1.xlsx', sheet_name='PT', usecols='O:T', header=1, skiprows=[2,3])

# %%
df.columns = [f'{my_col_name}_' + colname for colname in df.columns]

# %%
df.head()
# Out:
#    Porc_remocao_TS3  Porc_remocao_T3  Porc_remocao_TS7  Porc_remocao_T7  \
# 0          0.000000        46.153846         71.982759        63.934426
# 1          0.000000         0.000000         40.119760         3.947368
# 2         81.533477        92.317708         87.953288        89.902808
# 3         82.917466        90.524379         84.258417        96.583144
# 4         34.412955        51.785714         37.751004        75.378788
#
#    Porc_remocao_TS10  Porc_remocao_T10
# 0          61.674009         61.233480
# 1          20.118343         61.881188
# 2          93.808236         86.580341
# 3          92.844877         93.950178
# 4          33.760684         75.206612

# %% [markdown]
# ## Extra: Google Sheets

# %%
spreadsheet = 'https://docs.google.com/spreadsheets/d/1Z7-d5KHX07ZpEShCKEnN5DV3izcCjU0IwQv816kPZmE/edit?usp=sharing'
working_spreadsheet = spreadsheet.replace('/edit?usp=sharing','/export?format=csv&gid=0')

# %%
pd.read_csv(working_spreadsheet)
# Out:
#    Andre
# 0      1
# 1      2

# %% [markdown]
# ## Read from specific excel sheet

# %%
df = pd.read_excel('data/dados_artigo1.xlsx', sheet_name='dataset')
df.head()
# Out:
#    unplanted3   planted3  unplanted7   planted7  unplanted10  planted10  \
# 0    0.000000  78.636959   84.820995  52.068175    84.783652  85.310734
# 1    0.000000  14.616304   14.015557   0.000000    40.375704  28.928829
# 2   80.511993  89.752898   87.460473  89.376096    94.163425  87.193210
# 3   75.900402  87.403649   80.646947  93.727934    93.886463  94.274587
# 4   15.042991  69.794541   49.785408  82.442805    17.340252  78.333261
#
#   wether  parameter       date
# 0    wet  turbidity 2018-02-09
# 1    wet  turbidity 2018-02-15
# 2    wet  turbidity 2018-02-22
# 3    wet  turbidity 2018-03-01
# 4    wet  turbidity 2018-03-08

# %% [markdown]
# # Exporting datasets

# %% [markdown]
# ## Export TO EXCEL

# %%
df.to_excel('data/aldrey_treated_newversion.xlsx', sheet_name='treated')

# %% [markdown]
# ## BONUS: Saving to multiple sheets

# %%
writer = pd.ExcelWriter('data/aldrey_treated_new2.xlsx', engine = 'openpyxl')

# %%
df.to_excel(writer, sheet_name='treated')
df.to_excel(writer, sheet_name='untreated')

# %%
writer.save()
writer.close()

# %% [markdown]
# ## Export TO CSV

# %%
df.head()
# Out:
#    unplanted3   planted3  unplanted7   planted7  unplanted10  planted10  \
# 0    0.000000  78.636959   84.820995  52.068175    84.783652  85.310734
# 1    0.000000  14.616304   14.015557   0.000000    40.375704  28.928829
# 2   80.511993  89.752898   87.460473  89.376096    94.163425  87.193210
# 3   75.900402  87.403649   80.646947  93.727934    93.886463  94.274587
# 4   15.042991  69.794541   49.785408  82.442805    17.340252  78.333261
#
#   wether  parameter       date
# 0    wet  turbidity 2018-02-09
# 1    wet  turbidity 2018-02-15
# 2    wet  turbidity 2018-02-22
# 3    wet  turbidity 2018-03-01
# 4    wet  turbidity 2018-03-08

# %%
df.to_csv('data/exported_file_v1.csv')

# %%
df.to_csv('data/exported_file_v1.csv', index=False)

# %%
pd.read_csv('data/exported_file_v1.csv')
# Out:
#      unplanted3    planted3  unplanted7    planted7  unplanted10   planted10  \
# 0      0.000000   78.636959   84.820995   52.068175    84.783652   85.310734
# 1      0.000000   14.616304   14.015557    0.000000    40.375704   28.928829
# 2     80.511993   89.752898   87.460473   89.376096    94.163425   87.193210
# 3     75.900402   87.403649   80.646947   93.727934    93.886463   94.274587
# 4     15.042991   69.794541   49.785408   82.442805    17.340252   78.333261
# ..          ...         ...         ...         ...          ...         ...
# 215   65.309446   87.153652   74.054054   86.700913    63.328034   91.534091
# 216    0.000000   48.520710   38.206278    0.000000    34.740545   71.739130
# 217   28.395062   83.783784   66.559486  100.000000   100.000000  100.000000
# 218   59.640103  100.000000   44.281525  100.000000   100.000000  100.000000
# 219   10.194175  100.000000  100.000000  100.000000   100.000000  100.000000
#
#     wether  parameter        date
# 0      wet  turbidity  2018-02-09
# 1      wet  turbidity  2018-02-15
# 2      wet  turbidity  2018-02-22
# 3      wet  turbidity  2018-03-01
# 4      wet  turbidity  2018-03-08
# ..     ...        ...         ...
# 215    wet         pt  2018-10-05
# 216    wet         pt  2018-10-11
# 217    wet         pt  2018-10-18
# 218    wet         pt  2018-10-25
# 219    wet         pt  2018-10-31
#
# [220 rows x 9 columns]

# %%
# pd.read_csv('data/exported_file_v2.csv', index_col=0)

# %% [markdown]
# **NOTE**: If you do not specify the argument `index=False`, the output in the csv file will create an unnamed index column with the *dataframe indexes*.

# %%
df.to_csv('data/exported_file.csv', index=False)

# %% [markdown]
# ## Export to csv using a specific separator

# %% [markdown]
# ### Semicolon

# %%
df.to_csv('data/exported_file_semicolon.csv', index=False, sep=';')

# %% [markdown]
# ### Pipe

# %%
df.to_csv('data/exported_file_pipe.csv', index=False, sep='|')

# %% [markdown]
# ### plust or minus

# %%
df.to_csv('data/exported_file_plusminus.csv', index=False, sep='±')

# %% [markdown]
# # Import and export JSON files

# %% [markdown]
# What is a JSON file?

# %% [markdown]
# JSON 1:
# ```json
# { "name":"John", "age":30, "car":null }
# ```
#
# JSON 2:
# ```json
# {"students":[
#    {"name":"Andre", "age":23, "state":"SP"},
#    {"name":"Rafael", "age":28, "state":"RJ"},
#    {"name":"Claudia", "age":32, "state":"PA"},
#    {"name":"Lajos", "age":28, "state":"MA"}
# ]}
# ```

# %%
data = pd.read_json('data/vehicles.json')

# %%
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0          4  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1          6  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2          4  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3          6  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4          6  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# For a JSON file, you can have different `orient` options.
#
# `'split'`: Dictionary containing indexes, columns, and data.
#
# `'index'`: Nested dictionaries containing {index:{column:value}}.
#
# `'columns'`: Nested dictionaries containing {column:{index:value}}
#
# `'values'`: Nested list where each sublist contains the values for a record.
#
# `'table'`: Nested dictionaries containing schema and data (records).

# %%
data.sample(10)
# Out:
#             Make                  Model  Year  Engine Displacement  Cylinders  \
# 10819      Dodge                Stratus  1996                  2.4          4
# 15832        GMC        Sierra 1500 4WD  1991                  5.0          8
# 6841   Chevrolet         S10 Pickup 2WD  1989                  2.5          4
# 20391        Kia                 Amanti  2009                  3.8          6
# 5459   Chevrolet  Colorado Crew Cab 4WD  2012                  3.7          5
# 6056   Chevrolet                HHR FWD  2010                  2.0          4
# 32810     Toyota           Celica Supra  1985                  2.8          6
# 7596   Chevrolet         Tahoe 1500 4WD  2011                  5.3          8
# 26951     Nissan           Sentra Wagon  1985                  1.6          4
# 32228     Suzuki          Vitara 4 Door  2004                  2.5          6
#
#           Transmission                  Drivetrain  \
# 10819  Automatic 4-spd           Front-Wheel Drive
# 15832  Automatic 4-spd  4-Wheel or All-Wheel Drive
# 6841   Automatic 4-spd            Rear-Wheel Drive
# 20391  Automatic 5-spd           Front-Wheel Drive
# 5459   Automatic 4-spd               4-Wheel Drive
# 6056      Manual 5-spd           Front-Wheel Drive
# 32810  Automatic 4-spd            Rear-Wheel Drive
# 7596   Automatic 6-spd               4-Wheel Drive
# 26951  Automatic 3-spd           Front-Wheel Drive
# 32228  Automatic 4-spd            Rear-Wheel Drive
#
#                      Vehicle Class        Fuel Type  Fuel Barrels/Year  \
# 10819                 Midsize Cars          Regular          15.695714
# 15832       Standard Pickup Trucks          Regular          23.543571
# 6841           Small Pickup Trucks          Regular          15.695714
# 20391                   Large Cars          Regular          17.347895
# 5459       Small Pickup Trucks 4WD          Regular          18.311667
# 6056   Sport Utility Vehicle - 2WD          Regular          13.733750
# 32810              Subcompact Cars          Premium          17.347895
# 7596   Sport Utility Vehicle - 4WD  Gasoline or E85          19.388824
# 26951         Small Station Wagons          Regular          13.184400
# 32228  Sport Utility Vehicle - 2WD          Regular          18.311667
#
#        City MPG  Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# 10819        18           26            21               423.190476
# 15832        12           16            14               634.785714
# 6841         18           26            21               423.190476
# 20391        17           24            19               467.736842
# 5459         16           21            18               493.722222
# 6056         21           29            24               370.291667
# 32810        17           22            19               467.736842
# 7596         15           21            17               522.764706
# 26951        23           27            25               355.480000
# 32228        17           20            18               493.722222
#
#        Fuel Cost/Year
# 10819            1600
# 15832            2400
# 6841             1600
# 20391            1750
# 5459             1850
# 6056             1400
# 32810            2150
# 7596             1950
# 26951            1350
# 32228            1850

# %%
data.sample(10).to_json('data/vehicles_split.json', orient='split')
data.sample(10).to_json('data/vehicles_index.json', orient='index')
data.sample(10).to_json('data/vehicles_columns.json', orient='columns')
data.sample(10).to_json('data/vehicles_values.json', orient='values')
data.sample(10).to_json('data/vehicles_table.json', orient='table')

# %% [markdown]
# ## Encoding

# %%
#df.to_csv('data/teste.csv')

# %%
pd.read_csv('data/CSV.8859-1.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe1 in position 1: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-173-0792fe2a15f8> in <module>
# ----> 1 pd.read_csv('data/CSV.8859-1.csv')
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe1 in position 1: invalid continuation byte

# %%
pd.read_csv('data/CSV.8859-1.csv', encoding='latin-1', sep=';')
# Out:
#           Data Projeto(s)    Ini    Ter  Horas  \
# 0   qui, 02/01        GTE  11:30  12:00  00:30
# 1   qui, 02/01        GTE  13:00  13:30  00:30
# 2   qui, 02/01        GTE  13:30  14:00  00:30
# 3   qui, 02/01   GTE - FC  14:00  15:00  01:00
# 4   qui, 02/01        GTE  15:00  15:30  00:30
# ..         ...        ...    ...    ...    ...
# 93  qua, 29/01    PRODESP  16:30  17:30  01:00
# 94  qui, 30/01    PRODESP  14:00  18:00  04:00
# 95  sex, 31/01         RS  10:30  12:00  01:30
# 96  sex, 31/01        GTE  12:00  12:30  00:30
# 97  sex, 31/01    PRODESP  13:30  14:30  01:00
#
#                               Atividade  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0               Tarefas administrativas         NaN         NaN         NaN
# 1                  Apontamento de horas         NaN         NaN         NaN
# 2               Tarefas administrativas         NaN         NaN         NaN
# 3   Troubleshooting Contrato X Rubricas         NaN         NaN         NaN
# 4               Tarefas administrativas         NaN         NaN         NaN
# ..                                  ...         ...         ...         ...
# 93                       Sistemas APESP         NaN         NaN         NaN
# 94                       Sistemas APESP         NaN         NaN         NaN
# 95                  Revisão query Inova         NaN         NaN         NaN
# 96              Tarefas administrativas         NaN         NaN         NaN
# 97                       Sistemas APESP         NaN         NaN         NaN
#
#     Unnamed: 9
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 93         NaN
# 94         NaN
# 95         NaN
# 96         NaN
# 97         NaN
#
# [98 rows x 10 columns]

# %%
pd.read_csv('data/CSV.UTF8.csv', sep=';').sample(20)
# Out:
#           Data  Projeto(s)    Ini    Ter  Horas  \
# 90  ter, 28/01          RS  16:00  16:30  00:30
# 79  sex, 24/01  Paulistana  10:00  11:00  01:00
# 29  seg, 13/01  Paulistana  11:00  12:00  01:00
# 13  ter, 07/01     PRODESP  10:00  11:30  01:30
# 18  qua, 08/01    GTE - FC  10:30  12:00  01:30
# 91  ter, 28/01     PRODESP  16:30  18:00  01:30
# 58  dom, 19/01     PRODESP  02:30  12:00  09:30
# 42  qua, 15/01     PRODESP  10:30  11:30  01:00
# 44  qua, 15/01     PRODESP  12:30  13:30  01:00
# 20  qua, 08/01    GTE - FC  15:30  18:00  02:30
# 86  seg, 27/01          RS  14:00  16:00  02:00
# 89  ter, 28/01         GTE  15:00  16:00  01:00
# 51  qui, 16/01     PRODESP  16:30  17:00  00:30
# 15  ter, 07/01     PRODESP  14:00  15:30  01:30
# 53  sex, 17/01          RS  09:30  13:30  04:00
# 87  ter, 28/01     PRODESP  09:30  11:30  02:00
# 60  seg, 20/01     PRODESP  12:30  13:30  01:00
# 75  qui, 23/01          RS  13:30  14:00  00:30
# 66  ter, 21/01         GTE  13:30  14:00  00:30
# 96  sex, 31/01         GTE  12:00  12:30  00:30
#
#                                  Atividade  Unnamed: 6  Unnamed: 7  \
# 90         Automatização da extração Inova         NaN         NaN
# 79              Relatório de monitoramento         NaN         NaN
# 29             Performance das plataformas         NaN         NaN
# 13                  Planilhas de convênios         NaN         NaN
# 18         Estudo para módulo orçamentário         NaN         NaN
# 91                          Sistemas APESP         NaN         NaN
# 58                          Sistemas APESP         NaN         NaN
# 42                          Sistemas APESP         NaN         NaN
# 44       Sistema APESP - ambiente Maurício         NaN         NaN
# 20               Compilação das pendências         NaN         NaN
# 86                           Reunião CITEM         NaN         NaN
# 89            Reunião Financeiro - Backlog         NaN         NaN
# 51                   Ajuda a desenvolvedor         NaN         NaN
# 15                  Planilhas de convênios         NaN         NaN
# 53  Carga CGRH 12/2019 e atualização Inova         NaN         NaN
# 87                          Sistemas APESP         NaN         NaN
# 60                          Sistemas APESP         NaN         NaN
# 75     Sobre a extração da terceira edição         NaN         NaN
# 66        Preparação para reunião sobre AP         NaN         NaN
# 96                 Tarefas administrativas         NaN         NaN
#
#     Unnamed: 8  Unnamed: 9
# 90         NaN         NaN
# 79         NaN         NaN
# 29         NaN         NaN
# 13         NaN         NaN
# 18         NaN         NaN
# 91         NaN         NaN
# 58         NaN         NaN
# 42         NaN         NaN
# 44         NaN         NaN
# 20         NaN         NaN
# 86         NaN         NaN
# 89         NaN         NaN
# 51         NaN         NaN
# 15         NaN         NaN
# 53         NaN         NaN
# 87         NaN         NaN
# 60         NaN         NaN
# 75         NaN         NaN
# 66         NaN         NaN
# 96         NaN         NaN

# %% [markdown]
# # Importing files from URLs

# %% [markdown]
# Example: https://github.com/rfordatascience/tidytuesday

# %%
pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-06-09/firsts.csv')
# Out:
#      year                                     accomplishment  \
# 0    1738              First free African-American community
# 1    1760      First known African-American published author
# 2    1768  First known African-American to be elected to ...
# 3    1773  First known African-American woman to publish ...
# 4    1773             First separate African-American church
# ..    ...                                                ...
# 474  2019  First African-American to win an Academy Award...
# 475  2019  First member of the British royal family of Af...
# 476  2019  First African-American secretary of the Smiths...
# 477  2019  First African-American female director of an A...
# 478  2019  First African-American full-time curator at th...
#
#                                                 person  \
# 0    Gracia Real de Santa Teresa de Mose (later nam...
# 1              Jupiter Hammon (poem An Evening Thought
# 2    Wentworth Cheswell, town constable in Newmarke...
# 3    Phillis Wheatley (Poems on Various Subjects, R...
# 4    Silver Bluff Baptist Church, Aiken County, Sou...
# ..                                                 ...
# 474            Hannah Beachler for Black Panther [253]
# 475                         Archie Mountbatten-Windsor
# 476                                       Lonnie Bunch
# 477                                 Denise Verret[254]
# 478                                 Ashley James.[255]
#
#                              gender              category
# 0           African-American Firsts         Social & Jobs
# 1    Female African American Firsts  Arts & Entertainment
# 2           African-American Firsts         Social & Jobs
# 3    Female African American Firsts  Arts & Entertainment
# 4           African-American Firsts              Religion
# ..                              ...                   ...
# 474         African-American Firsts  Arts & Entertainment
# 475         African-American Firsts         Social & Jobs
# 476         African-American Firsts  Arts & Entertainment
# 477  Female African American Firsts  Arts & Entertainment
# 478         African-American Firsts  Arts & Entertainment
#
# [479 rows x 5 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-06-09/firsts.csv')
# Out:
#      year                                     accomplishment  \
# 0    1738              First free African-American community
# 1    1760      First known African-American published author
# 2    1768  First known African-American to be elected to ...
# 3    1773  First known African-American woman to publish ...
# 4    1773             First separate African-American church
# ..    ...                                                ...
# 474  2019  First African-American to win an Academy Award...
# 475  2019  First member of the British royal family of Af...
# 476  2019  First African-American secretary of the Smiths...
# 477  2019  First African-American female director of an A...
# 478  2019  First African-American full-time curator at th...
#
#                                                 person  \
# 0    Gracia Real de Santa Teresa de Mose (later nam...
# 1              Jupiter Hammon (poem An Evening Thought
# 2    Wentworth Cheswell, town constable in Newmarke...
# 3    Phillis Wheatley (Poems on Various Subjects, R...
# 4    Silver Bluff Baptist Church, Aiken County, Sou...
# ..                                                 ...
# 474            Hannah Beachler for Black Panther [253]
# 475                         Archie Mountbatten-Windsor
# 476                                       Lonnie Bunch
# 477                                 Denise Verret[254]
# 478                                 Ashley James.[255]
#
#                              gender              category
# 0           African-American Firsts         Social & Jobs
# 1    Female African American Firsts  Arts & Entertainment
# 2           African-American Firsts         Social & Jobs
# 3    Female African American Firsts  Arts & Entertainment
# 4           African-American Firsts              Religion
# ..                              ...                   ...
# 474         African-American Firsts  Arts & Entertainment
# 475         African-American Firsts         Social & Jobs
# 476         African-American Firsts  Arts & Entertainment
# 477  Female African American Firsts  Arts & Entertainment
# 478         African-American Firsts  Arts & Entertainment
#
# [479 rows x 5 columns]

# %%
af = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-06-09/firsts.csv')

# %%
af.head()
# Out:
#    year                                     accomplishment  \
# 0  1738              First free African-American community
# 1  1760      First known African-American published author
# 2  1768  First known African-American to be elected to ...
# 3  1773  First known African-American woman to publish ...
# 4  1773             First separate African-American church
#
#                                               person  \
# 0  Gracia Real de Santa Teresa de Mose (later nam...
# 1            Jupiter Hammon (poem An Evening Thought
# 2  Wentworth Cheswell, town constable in Newmarke...
# 3  Phillis Wheatley (Poems on Various Subjects, R...
# 4  Silver Bluff Baptist Church, Aiken County, Sou...
#
#                            gender              category
# 0         African-American Firsts         Social & Jobs
# 1  Female African American Firsts  Arts & Entertainment
# 2         African-American Firsts         Social & Jobs
# 3  Female African American Firsts  Arts & Entertainment
# 4         African-American Firsts              Religion

# %% [markdown]
# ## Extra: Dynamic table

# %%
pd.read_excel('data/dados_artigo1.xlsx', sheet_name='dinamica', skiprows=[0, 1,2])
# Out:
#      Row Labels          dry          wet  Grand Total
# 0         color   707.354118   561.762869  1269.116987
# 1           fev          NaN   167.050564   167.050564
# 2           mar          NaN   299.139626   299.139626
# 3           abr   365.311391          NaN   365.311391
# 4           mai   236.788123          NaN   236.788123
# ..          ...          ...          ...          ...
# 60          mai   258.426990          NaN   258.426990
# 61          jun   268.590074          NaN   268.590074
# 62          set     0.000000          NaN     0.000000
# 63          out          NaN    70.311359    70.311359
# 64  Grand Total  4273.776251  3976.096978  8249.873229
#
# [65 rows x 4 columns]

# %%
pd.read_csv('data/vehicles.zip')
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
pd.read_csv('data/data.7z')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-184-4494e686639d> in <module>
# ----> 1 pd.read_csv('data/data.7z')
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbc in position 2: invalid start byte
