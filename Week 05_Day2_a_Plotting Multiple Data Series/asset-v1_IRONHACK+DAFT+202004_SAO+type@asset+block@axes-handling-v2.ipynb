# %% [markdown]
# # Plotting in multiple axes

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Let's stop using plt.plot to gain more control.

# %% [markdown]
# ## Reading dataframe

# %%
df = pd.read_csv('data/exams.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group C            some high school  free/reduced
# 1  female        group C                some college  free/reduced
# 2    male        group A                 high school      standard
# 3    male        group B                some college      standard
# 4  female        group C             master's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          69             61             58
# 1               completed          47             65             69
# 2                    none          66             52             53
# 3                    none          88             89             82
# 4                    none          62             82             76

# %%
plt.scatter(df['reading score'], df['writing score'])

# %%
sns.scatterplot(df['reading score'], df['writing score'])

# %%
sns.distplot(df['writing score'])

# %% [markdown]
# ## Figures, Subplots, Axes and Ticks

# %% [markdown]
# When you call plt.plot, it implicitly creates an axes.

# %% [markdown]
# ### Subplots

# %%
fig, ax = plt.subplots(figsize=(1.61*5,5))

# %% [markdown]
# ## Como eu ploto no eixo que eu chamei de ax?

# %%
fig, ax = plt.subplots()

ax.scatter(df['reading score'], df['writing score'])

# %% [markdown]
# #### More than 1 subplot.
#
# You can specify how many rows and columns

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))

axes[1].scatter(df['reading score'], df['writing score'])
axes[0].scatter(df['math score'], df['writing score'])

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[1].scatter(df['reading score'], df['writing score'])

# %%
fig, axes = plt.subplots(nrows=2, ncols=1)

axes[0].scatter(df['reading score'], df['writing score'])

# %%
fig, axes = plt.subplots(nrows=2, ncols=1)

axes[0].scatter(df['reading score'], df['writing score'])

axes[1].scatter(df['math score'], df['writing score'])

# %% [markdown]
# #### Figsize
#
# Tuple containing the value of the size of the (x,y)

# %%
#plt.scatter() ...
#plt.xlabel('aosidjiosad')
#ax.set_xlabel('')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))

axes[0].scatter(df['reading score'], df['writing score'])
axes[1].scatter(df['math score'], df['writing score'])

axes[0].set_xlabel('My label x')
axes[0].set_ylabel('My label y')
axes[0].set_title('My title');

axes[1].set_xlabel('My label xxx')
axes[1].set_ylabel('My label yyyy')
axes[1].set_title('My titletiletile');

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002463673E6D8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000024637D4FC88>],
#       dtype=object)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,8))

ax1.scatter(df['reading score'], df['writing score'])
ax2.scatter(df['math score'], df['writing score'])

ax1.set_xlabel('X')
ax2.set_ylabel('Y LABEL do eixo 2')
# Out:
# Text(0, 0.5, 'Y LABEL do eixo 2')

# %%
x = np.array([1,2,3,4,5,6,7])

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,8))
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024637FA7400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024637FE4BA8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024638013DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024638049F98>]],
#       dtype=object)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,8))

axes[0,1].scatter(x, x)
axes[1,0].scatter(x, x**2)

# %%
fig = plt.figure()

fig.add_subplot(2, 2, 3)
fig.add_subplot(2, 2, 2)
fig.add_subplot(2, 2, 4)

# %%
fig = plt.figure()

fig.add_subplot(2,2, 1)
plt.plot(x, x)

fig.add_subplot(2,2, 4)
plt.plot(x, x**2)

# %% [markdown]
# ## Axes

# %%
fig, ax = plt.subplots()

ax.plot(x, x)

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.05,0.7,0.4,0.2])

ax1.plot(x, x**2, color='red')
ax2.plot(x, x)


ax1.set_title('Title')

ax2.set_xlabel('XLABEL')
# Out:
# Text(0.5, 0, 'XLABEL')

# %%
fig = plt.figure()

# [left, bottom, width, height]
ax1 = fig.add_axes([0, 0, 1.0, .4])

ax2 = fig.add_axes([0, 0.5, 0.4, 0.4])

# %%
fig = plt.figure(figsize=(6,3))

ax1 = fig.add_axes([0, 0.5, 1.0, 0.4])
ax2 = fig.add_axes([0, 0, 0.8, 0.4])
ax3 = fig.add_axes([0, 0.2, 0.5, 0.4])

x = np.arange(0, 3, 0.1)

ax1.plot(x, np.sin(x))
ax2.plot(x, np.exp(x))
ax3.plot(x, x**2)
plt.show()

# %% [markdown]
# ### Setting parameters

# %%
fig = plt.figure()

ax1 = fig.add_axes([0, 0.6, 1.2, 0.4])
ax2 = fig.add_axes([0, 0, 0.8, 0.4])


x = np.arange(0, 3, 0.1)

ax1.plot(x, np.sin(x))
ax2.plot(x, np.exp(x))

ax1.set_xlabel('x', fontsize=15, color='red')
ax1.set_ylabel('y', fontsize=15, color='red')
ax1.set_title('sin(x)', fontsize=15, color='red')
# Out:
# Text(0.5, 1.0, 'sin(x)')

# %% [markdown]
# # Using pandas plotting

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group C            some high school  free/reduced
# 1  female        group C                some college  free/reduced
# 2    male        group A                 high school      standard
# 3    male        group B                some college      standard
# 4  female        group C             master's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          69             61             58
# 1               completed          47             65             69
# 2                    none          66             52             53
# 3                    none          88             89             82
# 4                    none          62             82             76

# %%
plt.hist(df['math score'])
plt.show()

# %%
df['math score'].plot(kind='hist')

# %%
df['math score'].plot(kind='kde')

# %%
df.plot(kind='kde')

# %% [markdown]
# ### Adding pandas plotting to subplots

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,5))

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,5))

df['writing score'].plot(kind='hist', ax=axes[1])
df['math score'].plot(kind='hist', ax=axes[1])

# %% [markdown]
# # Adding axes wherever I want.

# %%
fig = plt.figure()

ax1 = fig.add_axes([0, 0.6, 1.2, 0.4])
ax2 = fig.add_axes([0, 0, 0.8, 0.4])

df['math score'].plot(kind='kde', ax=ax1)
df['math score'].plot(kind='hist', ax=ax2)

# %%
fig = plt.figure()

ax1 = fig.add_axes([0, 0.6, 1.2, 0.4])
df['math score'].plot(kind='kde')

ax2 = fig.add_axes([0, 0, 0.8, 0.4])
df['math score'].plot(kind='hist')

# %%
fig, axes = plt.subplots(1, 2)

df['math score'].plot(kind='kde', ax=axes[0])
df['math score'].plot(kind='hist', ax=axes[1])

# %% [markdown]
# ## Practical examples

# %% [markdown]
# The closing price of 10 stocks on the first trading day of each month from Jan 2007 to Jan 2017.

# %%
stock_data = pd.read_csv('data/stocks.csv')
stock_data.head()
# Out:
#        Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0  3-Jan-07  11.107141  38.869999  50.777351  251.001007  79.242500
# 1  1-Feb-07  10.962033  39.250000  48.082939  224.949951  74.503204
# 2  1-Mar-07  12.037377  41.700001  51.900383  229.309311  75.561348
# 3  2-Apr-07  12.930043  41.560001  54.588032  235.925919  81.934280
# 4  1-May-07  15.701322  44.060001  57.598267  249.204208  85.786057
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198
# 3  16.924608  23.480597  3.167143  17.196436  13.984914
# 4  17.111704  24.146753  3.128572  17.726965  12.988567

# %%
stock_data['Date'] = pd.to_datetime(stock_data['Date'])
stock_data.head()
# Out:
#         Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0 2007-01-03  11.107141  38.869999  50.777351  251.001007  79.242500
# 1 2007-02-01  10.962033  39.250000  48.082939  224.949951  74.503204
# 2 2007-03-01  12.037377  41.700001  51.900383  229.309311  75.561348
# 3 2007-04-02  12.930043  41.560001  54.588032  235.925919  81.934280
# 4 2007-05-01  15.701322  44.060001  57.598267  249.204208  85.786057
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198
# 3  16.924608  23.480597  3.167143  17.196436  13.984914
# 4  17.111704  24.146753  3.128572  17.726965  12.988567

# %% [markdown]
# ### Compare prices from AAPL, GOOG, MSFT and NFLX

# %%
#stock_data[['AAPL']].plot()
plt.plot(stock_data['AAPL'])

# %%
figure, axes = plt.subplots(2, 2, figsize=(15, 9))

axes[0,1].plot(stock_data['AAPL'])
axes[0,1].set_title('AAPL')


stock_data['MSFT'].plot(ax=axes[0,0])
axes[0,0].set_title('MSFT')

axes[1,0].plot(stock_data['MDLZ'])
axes[1,0].set_title('MDLZ')

stock_data['NFLX'].plot(ax=axes[1,1])
axes[1,1].set_title('NFLX')


for i in range(axes.shape[0]):
    for j in range(axes.shape[1]):
        print(f'Arrumando: {i,j}')
        axes[i,j].set_ylim([0, 150])
# Out:
# Arrumando: (0, 0)
# Arrumando: (0, 1)
# Arrumando: (1, 0)
# Arrumando: (1, 1)

# %%
figure.savefig('salv.png')
