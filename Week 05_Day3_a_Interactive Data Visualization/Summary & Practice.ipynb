# %% [markdown]
# # Interactive Visualization

# %% [markdown]
# ## import libraries and dataset

# %%
# import libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy
# Out:
# C:\Users\shcle\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df= pd.read_csv("./data/churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ### df.sample()

# %%
df2= df.sample(100) # Return a random sample of items from an axis of object
df2.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5556  5364-EVNIB    Male              0      No         No      13
# 4590  4884-TVUQF  Female              1      No         No      57
# 3026  6127-ISGTU  Female              0     Yes         No      16
# 1444  5514-YQENT    Male              0      No        Yes      41
# 1763  6519-CFDBX  Female              0      No         No       2
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 5556          Yes            No     Fiber optic             No  ...
# 4590          Yes           Yes     Fiber optic            Yes  ...
# 3026          Yes           Yes     Fiber optic             No  ...
# 1444          Yes            No     Fiber optic            Yes  ...
# 1763          Yes            No             DSL             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# ### df.dtypes / df.column.astype(float)

# %%
df2.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# TotalCharges --> object --> float
df2.TotalCharges = df2.TotalCharges.astype(float)
df2.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %% [markdown]
# ## fig, ax = plt.subplots()

# %%
# Create a figure and a set of subplots
fig, ax = plt.subplots()

# %% [markdown]
# ### plt.figure() / fig.add_axes()

# %% [markdown]
# > - The dimensions [left, bottom, width, height] of the new axes:
# >```python
#  fig.add_axes(rec=[left, bottom, width, height])
# >```

# %%
# Create a new figure
fig = plt.figure() 

# Add an axes to the figure
ax1 = fig.add_axes([0, 0, 0.7, 0.5])    
ax2 = fig.add_axes([0.5, 0, 0.7, 0.3])

# scatter plots
ax1.scatter(df2['tenure'], df2['MonthlyCharges'])
ax2.scatter(df2['tenure'], df2['TotalCharges'])

# %% [markdown]
# ### df.plot( kind='scatter', x, y)

# %%
df2.plot(kind='scatter', x='tenure', y='TotalCharges')

# %% [markdown]
# ### df.column.plot ( kind= , ax=  ) / sns.countplot ( df.column, ax=  )

# %%
# Create a new figure
fig = plt.figure() 

# Add an axes to the figure
ax1 = fig.add_axes([0, 0, 0.7, 0.5])   
ax2 = fig.add_axes([0.5, 0, 0.7, 0.3])

# Plot ax2
df2[['MonthlyCharges']].plot(kind='kde', ax=ax2)

# Plot ax1 using seaborn
sns.countplot(df2['tenure'], ax=ax1)

# %% [markdown]
# ---

# %% [markdown]
# # Install Cutfflinks

# %% [markdown]
# ## cf.go_offline()

# %%
#!pip install cufflinks==0.16.0

# %%
#import library
import cufflinks as cf

cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Acess dataset

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ### pd.to_numeric(df.column, errors='coerce')

# %%
# To change df.column to numeric data type
df['MonthlyCharges'] = pd.to_numeric(df['MonthlyCharges'], errors='coerce')
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %% [markdown]
# # df. iplot()

# %% [markdown]
# ##  Histogram : df.column.iplot ( kind='hist' )

# %%
df['TotalCharges'].plot(kind='hist')

# %%
# Interactive histogram 1
df['TotalCharges'].iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="8e401385-6a42-476b-a3f1-c02840e7d01a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8e401385-6a42-476b-a3f1-c02840e7d01a")) {
#                     Plotly.newPlot(
#                         '8e401385-6a42-476b-a3f1-c02840e7d01a',
# ...

# %%
# Interactive histogram 2
df['TotalCharges'].iplot(kind='hist', 
                         title='Total Charges Histogram', 
                         xTitle='Total Charges', 
                         yTitle='Frequency')
# Out:
# <div>
#
#
#             <div id="35d5b2b3-02eb-4608-b823-ff8314c6d0f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("35d5b2b3-02eb-4608-b823-ff8314c6d0f0")) {
#                     Plotly.newPlot(
#                         '35d5b2b3-02eb-4608-b823-ff8314c6d0f0',
# ...

# %% [markdown]
# ## Bar chart: df. iplot ( kind='bar', x= column)

# %% [markdown]
# ### df.column.apply (lambda x: 1 if x== 'Yes' else 0)

# %%
# create variable ChurnBinary (1-0) based on Churn (Yes-No)
df['ChurnBinary'] = df['Churn'].apply(lambda x : 1 if x == 'Yes' else 0)
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df.PaymentMethod.unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
# get the average of churn for each payment method
data = df.groupby('PaymentMethod', as_index=False)['ChurnBinary'].mean()
data
# Out:
#                PaymentMethod  ChurnBinary
# 0  Bank transfer (automatic)     0.167098
# 1    Credit card (automatic)     0.152431
# 2           Electronic check     0.452854
# 3               Mailed check     0.191067

# %%
data.plot(kind='bar', x='PaymentMethod')

# %%
# Interactive bar chart
data.iplot(kind='bar', x='PaymentMethod')
# Out:
# <div>
#
#
#             <div id="cf242985-80b7-495a-a76f-4a58b0997bce" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cf242985-80b7-495a-a76f-4a58b0997bce")) {
#                     Plotly.newPlot(
#                         'cf242985-80b7-495a-a76f-4a58b0997bce',
# ...

# %% [markdown]
# ## Line chart : df.iplot ( kind='line', x=column)

# %%
# tenure: tempo de casa

data = df.groupby('tenure', as_index=False).agg({'ChurnBinary':'mean'})
data.head()
# Out:
#    tenure  ChurnBinary
# 0       0     0.000000
# 1       1     0.619902
# 2       2     0.516807
# 3       3     0.470000
# 4       4     0.471591

# %%
data.plot(kind='line', x='tenure')

# %%
# Interactive line chart
data.iplot(kind='line', x='tenure', title='Churn vs Tenure')
# Out:
# <div>
#
#
#             <div id="f02d0c4f-7e65-4c0f-a17c-40f246fec4bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f02d0c4f-7e65-4c0f-a17c-40f246fec4bf")) {
#                     Plotly.newPlot(
#                         'f02d0c4f-7e65-4c0f-a17c-40f246fec4bf',
# ...

# %% [markdown]
# ## Scatter Plot : df.iplot (x, y, mode='marker', categories='column')

# %%
df.iplot(x='tenure', y='TotalCharges', mode='markers')
# Out:
# <div>
#
#
#             <div id="e9dee466-fa74-4ad1-8adc-2b7cf42119ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e9dee466-fa74-4ad1-8adc-2b7cf42119ba")) {
#                     Plotly.newPlot(
#                         'e9dee466-fa74-4ad1-8adc-2b7cf42119ba',
# ...

# %% [markdown]
# > **Too much info on the graph, which is difficult to understand**

# %%
df.shape
# Out:
# (7043, 22)

# %% [markdown]
# > split the information, using mask ou query

# %%
df.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
df.PaymentMethod.unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
# 1 year contract & payment with credit card 
data = df.query('Contract == "One year" and PaymentMethod == "Credit card (automatic)"')
data.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 54  4667-QONEA  Female              1     Yes        Yes      60          Yes
# 56  8769-KKTPH  Female              0     Yes        Yes      63          Yes
# 63  0557-ASKVU  Female              0     Yes        Yes      18          Yes
# 76  6416-JNVRK  Female              0      No         No      46          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... TechSupport StreamingTV  \
# 12           Yes     Fiber optic             No  ...          No         Yes
# 54            No             DSL            Yes  ...         Yes          No
# 56           Yes     Fiber optic            Yes  ...          No         Yes
# 63            No             DSL             No  ...         Yes          No
# 76            No             DSL             No  ...          No          No
#
# ...

# %%
data.iplot(x='tenure', y='TotalCharges', mode='markers')
# Out:
# <div>
#
#
#             <div id="df229c4e-5bfa-4599-ac57-a6161ed0393c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("df229c4e-5bfa-4599-ac57-a6161ed0393c")) {
#                     Plotly.newPlot(
#                         'df229c4e-5bfa-4599-ac57-a6161ed0393c',
# ...

# %% [markdown]
# ### argument : categories= 'column'      -> like hue=

# %%
data.iplot(x='tenure', y='TotalCharges', mode='markers', categories='InternetService')
# Out:
# C:\Users\shcle\Anaconda3\lib\site-packages\cufflinks\plotlytools.py:805: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\shcle\Anaconda3\lib\site-packages\cufflinks\plotlytools.py:808: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="862d27ab-e6e9-4375-9e97-eb4154650a76" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("862d27ab-e6e9-4375-9e97-eb4154650a76")) {
#                     Plotly.newPlot(
#                         '862d27ab-e6e9-4375-9e97-eb4154650a76',
# ...

# %% [markdown]
# # Bubble chart : df.iplot (kind='bubble' , x, y, size='column')

# %%
data = data.query('PhoneService == "No"')

data.iplot(kind='bubble', x='tenure', y='MonthlyCharges', size='TotalCharges',
           xTitle='Tenure',
           categories='InternetService')
# Out:
# C:\Users\shcle\Anaconda3\lib\site-packages\cufflinks\plotlytools.py:805: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\shcle\Anaconda3\lib\site-packages\cufflinks\plotlytools.py:808: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="aef392b3-3da7-48c3-9bab-840cc9e2a6c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("aef392b3-3da7-48c3-9bab-840cc9e2a6c7")) {
#                     Plotly.newPlot(
#                         'aef392b3-3da7-48c3-9bab-840cc9e2a6c7',
# ...

# %% [markdown]
# ## Box plot : df.column.iplot (kind='box')

# %%
df[['TotalCharges']].iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="b1260501-fc7d-4e48-8a0b-504f73856143" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b1260501-fc7d-4e48-8a0b-504f73856143")) {
#                     Plotly.newPlot(
#                         'b1260501-fc7d-4e48-8a0b-504f73856143',
# ...

# %% [markdown]
# # IPyWidgets : from ipywidgets import interact

# %%
from ipywidgets import interact

# %%
df['TotalCharges'].iplot(kind='hist', bins=100, title='Tenure Distribution')
# Out:
# <div>
#
#
#             <div id="d44d5e89-b9d1-4ab1-aa12-8d587ae90b72" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d44d5e89-b9d1-4ab1-aa12-8d587ae90b72")) {
#                     Plotly.newPlot(
#                         'd44d5e89-b9d1-4ab1-aa12-8d587ae90b72',
# ...

# %% [markdown]
# ## def plot_graph(bin)

# %%
def plot_graph(bins):
    df['TotalCharges'].iplot(kind='hist', bins=bins, title='Tenure Distribution')

# %% [markdown]
# ## interact(function_name, arguments= ( , , ))

# %%
interact(plot_graph, bins=(0,100,10)) # (start, stop, step)
# Out:
# interactive(children=(IntSlider(value=50, description='bins', step=10), Output()), _dom_classes=('widget-inter…
# <function __main__.plot_graph(bins)>

# %% [markdown]
# ## @interact(arguments=( , , ))  / function {df.iplot()}

# %%
@interact(bins = (5, 50, 5))
def plot_graph(bins):
    df['TotalCharges'].iplot(kind='hist', bins=bins, title='Tenure Distribution')

# %% [markdown]
# ##  @interact(arguments=[ , ]) / function { df.query / df.iplot }

# %%
@interact(churn=[True, False])
def plot_graph(churn):
    data =df.query(f'ChurnBinary == {churn}')
    
    data['tenure'].iplot(kind='hist', bins=50, title='Tenure Distribution')
# Out:
# interactive(children=(Dropdown(description='churn', options=(True, False), value=True), Output()), _dom_classe…

# %% [markdown]
# ---

# %%
list(df['InternetService'].unique())
# Out:
# ['DSL', 'Fiber optic', 'No']

# %%
@interact(Gender=list(df['gender'].unique()), 
          Partner=list(df['Partner'].unique()),
          Internet=list(df['InternetService'].unique()), 
          Payment=list(df['PaymentMethod'].unique())
         )

def scatter(Gender, Partner, Internet, Payment):
    
    data = df.loc[(df['gender']==Gender) & 
                  (df['Partner']==Partner) & 
                  (df['InternetService']==Internet) & 
                  (df['PaymentMethod']==Payment), :]

    data.iplot(kind='scatter', x='tenure', y='MonthlyCharges', 
               categories='Contract', text='customerID', 
               xTitle='Tenure', yTitle='Monthly Charges',
               title='Charges vs. Tenure')
# Out:
# interactive(children=(Dropdown(description='Gender', options=('Female', 'Male'), value='Female'), Dropdown(des…

# %% [markdown]
# # Interactivity is not limited to plots
#
# One can use the `display` function to show dataframes interactively.

# %% [markdown]
# ## from IPython.display import display

# %%
from IPython.display import display

display(df.head())
display(df.head(3))
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
@interact(gender=list(df['gender'].unique()),  
          payment=list(df['PaymentMethod'].unique()))
         
def report(gender, payment):
    condition = (df.gender == gender) & (df.PaymentMethod == payment)
    data = df.loc[condition, :]
    
    display(data.groupby('Churn').mean())
# Out:
# interactive(children=(Dropdown(description='gender', options=('Female', 'Male'), value='Female'), Dropdown(des…

# %% [markdown]
# ## Pandas Styling :  .display(  df.style.highlight_max() )

# %%
from IPython.display import display

@interact(payment=['Electronic check', 'Mailed check'])  

def report(payment):
    condition = df.PaymentMethod == payment
    data = df.loc[condition, :]
    
    display(data.groupby('Churn').mean().style.highlight_max())
# Out:
# interactive(children=(Dropdown(description='payment', options=('Electronic check', 'Mailed check'), value='Ele…
